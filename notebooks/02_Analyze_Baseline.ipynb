# %%
###### IMPORT ######
import librosa as lr                  # specialized in loading, analyzing and visualizing adio datas 
import librosa.display
import matplotlib.pyplot as plt
import os
import numpy as np
from IPython.display import Audio     # creates an HTML player we can easly use here

# %%
###### LOADING THE AUDIOS ######
files = [f for f in os.listdir('../data/generated/') if f.endswith('wav')]
files.sort()
print(f'files = {files}')

amplitudes = {}
sampling_rates = {}

for i, file in enumerate(files):
    print(f'loading sample {i+1}...')
    file_path = os.path.join('../data/generated/', file)
    amp, sr = lr.load(file_path)                          # It returns the amplitudes (numpy array) and the sampling rate for each audio
    amplitudes[file] = amp
    sampling_rates[file] = sr
    
print('Successfully loaded')
# Out:
# files = ['sample_1_a_90s_rock_song_with.wav', 'sample_2_a_calm_relaxing_lofi.wav', 'sample_3_epic_cinematic_music.wav', 'sample_4_a_simple_melancholic.wav']
# loading sample 1...
# loading sample 2...
# loading sample 3...
# loading sample 4...
# Successfully loaded

# %%
###### CREATING AUDIO PLAYER ######
i = 1
for file, amp in amplitudes.items():
    sr = sampling_rates[file]
    print(f'\n---sample {i}---')
    display(Audio(data = amp, rate = sr))
    i += 1
# Out:
# ---sample 1---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---sample 2---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---sample 3---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---sample 4---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
###### PLOTTING ######
plt.rcParams['figure.figsize'] = [15, 8] # Sets the size for each graph
i = 1

for file, amp in amplitudes.items():
    sr = sampling_rates[file]
    print(f"\n---{f'sample {i} analysis'}---")
    fig, axs = plt.subplots(1, 2, sharex=True) 
    
    # Waveform
    librosa.display.waveshow(amp, sr=sr, ax=axs[0])
    axs[0].set_title('Waveform')
    axs[0].set_ylabel('Amplitude')
    axs[0].grid(True) 
    
    # Spectrogram
    D = librosa.stft(amp)  # Computes the Short-Time Fourier Transform. The Fourier Transform is a mathematical tool that decomposes 
                           # an audio signal into its fundamental frequency components: here, librosa divides 'amp' into short
                           # time windows of 2048 samples each, on which it applies the FT. The result is a 1025x429 matrix of complex
                           # numbers: the 1025 rows represent different frequencies from 0Hz to 16.000Hz (the rule is f_k = k*(sr/2048) for
                           # the k^th row), while the 429 cols are the windows in wich the audio has been divided. 

                           # Each complex number contains information about the wave's amplitude and phase in that specific moment.
                           # To plot the spectogram, we only need in the amplitude, which is given by the magnitude of the complex number.
    
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max) # these magnitudes are converted to decibels: 'ref=np.max' means that the maximum 
                                                          # amplitude value is mapped to 0dB, and all other values are scaled accordingly.
                                                          # This means that S_db is now full of non-positive numbers (from -80dB to 0dB).
    
    img = librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='log', ax=axs[1], cmap='magma')
    # We use a logaritmic scale because it's the way we perceive sounds. In fact, most of the musical information is found in the low 
    # frequencies and if we kept the linear scale, this part would be heavily compressed and the graph would be impossible to interpret.
    
    axs[1].set_title('Spectrogram')
    axs[1].set_ylabel('Frequency (Hz)')
    
    fig.colorbar(img, ax=axs[1], format='%+2.0f dB', label='Intensity')
    plt.tight_layout()
    plt.show()

    i += 1
# Out:
# ---sample 1 analysis---
# ---sample 2 analysis---
# ---sample 3 analysis---
# ---sample 4 analysis---

# %%
'''--- CHART ANALYSIS📈 ---

In the waveform display of an audio to be restored, the following defects can typically be identified:

    ·Clipping: it occurs when the signal is so strong that it exceeds the maximum limit (+-1). The result is a 
               clean cut of the top (or bottom) of the wave, which causes a harsh and unpleasant sound.
               
    ·Low dinamic range: dinamic range is the difference between the softest and the loudest parts of the audio. If it's small
                        we perceive the sound as flat and lifeless. Visually, the waveform appears more compact and rectangular.
                        
    ·DC offset: a DC signal (Direct Current) has a constant, non-zero value, whereas sound waves are AC signals (Alternating Current) 
                that oscillate symmetrically around zero (absolute silence). DC offset refers to the presence of an unwanted DC 
                component in an AC signal. In a waveform display, it appears as the entire waveform being slightly shifted up or 
                down relative to the x-axis, and it can cause the characteristic ‘pop’ at the start and end of the audio due to the  
                speaker which has to 'jump' from zero to the offset position and back.
                
In the spectrogram, on the other hand, we may observe the following features:

    ·High-Frequency cutoff: the audio is devoid of all frequencies above a certain threshold. We can see at the top of the graph
                            that all colors disappear and there's only a black strip. The audio will appear muffled and dull. 
                            
    ·Broadband noise: it's the typical background 'hiss' or 'breath' noise. It appears as a fine 'grain' uniformly spread over the 
                      entire spectrogram.
                      
    ·Narrowband noise: we can see it when a continuos whistle or hum is present during the whole audio. It appears like one or more 
                        horizontal lines running through the graph.'''

# %%
''' --- IN THIS SPECIFIC CASE ---

    ·Sample 1: in the waveform display, the audio shows low dinamic range, with the wave appearing compact and rectangular. 
               Given that it's a rock song, this might not be a defect but rather a feature of the style.
               On the other hand, the spectrogram reveals the main defects of the audio:
                   ·high-frequency cutoff;
                   ·narrowband noise;
                   ·in the mid-to-high frequency range (2 kHz to 8 kHz), the energy looks grainy, with a lack of clarity in the 
                    real instruments.

    ·Sample 2: while the waveform display seemes to be clean and well-defined, the spectrogram shows:
                   ·high-frequancy cutoff; 
                   ·a distinct black gap between the notes, suggesting a choppy sound (not very natural for a lo-fi style);
                   ·vertical banding caused by drum hits that are too abrupt and spaced apart.

    ·Sample 3: main problems appears in the spectrogram:
                   ·high-frequancy cutoff; 
                   ·broadband noise, visible in the first few seconds as a violet haze;
                   ·thin horizontal lines;
                   ·the energy appears 'muddy,' with poor separation and clarity between the various orchestra instruments.

    ·Sample 4: we can clearly observe the high-frequency cutoff and the absence of musical complexity: The piano harmonics (like
               'ghost notes' that accompany every real note and define its character) are present but sound overly 'clean', with a sharp
               cutoff at 8 kHz. The timbral richness typical of a real piano is lacking.'''
